# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import pydeck as pdk

# 포스트 데이터 불러오기
df_post = pd.read_csv('../inputs/posts/euljiro.csv', index_col=0)

# 텍스트 없으면 drop
df_post = df_post.dropna()

# %%
df_post.head()
# Out:
#                        date location  \
# 0  2023-11-10T05:20:04.000Z   을지로 3가
# 1  2023-11-07T12:29:08.000Z   을지로 3가
# 2  2023-12-25T09:13:20.000Z   을지로 3가
# 3  2023-12-23T15:51:57.000Z   을지로 3가
# 4  2023-11-09T02:56:31.000Z   을지로 3가
#
#                                                 text
# 0                    .을지로의 상징이 되어버린 올디스😁⠀네온사인이 참 이쁘다
# 1  일본식 중화요리를 선보이는 을지로 신상 맛집 -각양각색의 맛집들이 모여 있는을지로 ...
# 2                                 🎄......#스냅사진 #스냅모델
# 3  블랜딩밀크가 들어가 고소하고 부드러운 라떼 맛집☕️을지로 인쇄골목 사이에 위치한 #...
# 4  손에서 컵을 못 놓겠네..☕️...이번에 착용한 데님은 학교 동아리에서 스프레이로 ...

# %%
# 12월로 데이터 필터링

df_post = df_post.loc[df_post.loc[:,'date'].str.contains('2023-12')]

# %%
# 상점 데이터 불러오기
gdf_store_euljiro = gpd.read_file('../inputs/stores/store_euljiro.geojson')

# 음식점만 필터링
gdf_store_euljiro = gdf_store_euljiro.loc[gdf_store_euljiro.loc[:,'상권업종대분류명'] == '음식']

# 상호명 없는 상점은 삭제
gdf_store_euljiro = gdf_store_euljiro.dropna(subset='상호명')

# 상호명과 geometry만 남기고 다 삭제 (현재 필요없는 컬럼들)
gdf_store_euljiro = gdf_store_euljiro.loc[:,['상호명', 'geometry']]

# 상호명: store_name으로 변경
gdf_store_euljiro = gdf_store_euljiro.rename(columns={'상호명':'store_name'})

# %%
gdf_store_euljiro.head()
# Out:
#    store_name                    geometry
# 6         르템플  POINT (126.99240 37.56589)
# 7     낮한끼저녁한잔  POINT (126.98923 37.56513)
# 10         일품  POINT (126.98958 37.56533)
# 14          휘  POINT (126.99265 37.56306)
# 17         죽향  POINT (126.98938 37.56465)

# %%
def counting_post(store_name):
    '''
    상점 이름을 input으로 받아 posting 갯수를 세주는 함수

    input:
        store_name (string): 상호명
    output:
        posting_count (int): 포스팅 갯수

    '''

    # 상점 이름 을지인 것은 패스
    if store_name == '을지':
        return 0

    # 상호명이 한글자이면 그냥 0개로 취급
    if len(store_name) == 1:
        return 0

    # 포스트 중에서 상점 이름이 포함되어 있으면 좌표 추가
    posting_count = df_post.loc[df_post.loc[:,'text'].str.contains(store_name, regex=False)].shape[0]

    return posting_count

# %%
gdf_store_euljiro.loc[:,'posting_count'] = gdf_store_euljiro.loc[:,'store_name'].apply(counting_post)

# %%
# 포스팅 갯수 기준으로 정렬
gdf_store_euljiro = gdf_store_euljiro.sort_values(by='posting_count', ascending=False)

# %%
for i, row in gdf_store_euljiro.iterrows():
    print(row['store_name'], row['posting_count'])
    if row['posting_count'] == 0:
        break
# Out:
# 또롱 20
# 을지로술집 19
# 갤러리 15
# 공간갑 4
# 베로나 4
# 효계 4
# 을지로라스베가스 3
# 부장님댁 3
# 타마고 3
# 코야 3
# 을지오뎅 3
# 을지1막 3
# 돈독 3
# 토리노라스베가스 3
# 우르르 2
# 어나더레벨 2
# 분카샤 2
# 82올리언즈 2
# 부지 2
# 주마등 2
# 광장 2
# 다래 2
# 일품 2
# 오덕장 2
# 을지빈 2
# 까이9 2
# 을지로밑 2
# 일단 2
# 만선호프 1
# 다크문 1
# 을지맥옥 1
# 애플 1
# 을지도 1
# 을지로보석 1
# 십분의일 1
# 을지로골목집 1
# 굿모닝 1
# 맨틱 1
# 줄리아 1
# 을지깐깐 1
# 부스 1
# 취향로3가 1
# 좋은날 1
# 금토일샴페인빠 1
# 혜민당 1
# 302호 1
# 라이너 1
# 만선 1
# 전주집 1
# 수선화 1
# 코너숍 1
# 르템플 1
# 드므 1
# 단칸 1
# 가야성 1
# 콸콸 1
# 남영동양문 1
# 영동 1
# 낭만 1
# 을지다락 1
# 을지로제 1
# 동강나루터 0

# %%
# 상점명 중 너무 보편적이여서 배제할 단어들을 우선 눈으로 리스팅 
list_stopwords = ['오늘', '충무', '을지로술집', '아트', '갤러리', '블루커피베이크', '현대', '선물', '연락', '디어', '충무로맛집', '광고', '포인트', '세운', '나무', '청계', '일단', '맛나', '가자', '무한', '힐링', '낭만', '인쇄소', '남산', '디엠']

# %%
# list_stopwords 안에 있는 상점들은 우선 데이터프레임에서 제외
gdf_store_euljiro = gdf_store_euljiro.loc[~gdf_store_euljiro.loc[:,'store_name'].isin(list_stopwords)]

# 포스팅 수가 0인 것들도 데이터프레임에서 제외
gdf_store_euljiro = gdf_store_euljiro.loc[gdf_store_euljiro.loc[:,'posting_count']>0]

# %%
# 약 372개 장소가 살아남음
gdf_store_euljiro
# Out:
#      store_name                    geometry  posting_count
# 215          또롱  POINT (126.99055 37.56517)             20
# 973         공간갑  POINT (126.99026 37.56549)              4
# 238         베로나  POINT (126.99146 37.56547)              4
# 77           효계  POINT (126.99113 37.56544)              4
# 151    을지로라스베가스  POINT (126.99055 37.56517)              3
# 582        부장님댁  POINT (126.99122 37.56539)              3
# 408         타마고  POINT (126.98847 37.56670)              3
# 1461         코야  POINT (126.99055 37.56517)              3
# 106        을지오뎅  POINT (126.98992 37.56592)              3
# 263        을지1막  POINT (126.99147 37.56532)              3
# 1391         돈독  POINT (126.99141 37.56374)              3
# 552    토리노라스베가스  POINT (126.98933 37.56487)              3
# 1482        우르르  POINT (126.99270 37.56402)              2
# 1389      어나더레벨  POINT (126.99125 37.56564)              2
# 560         분카샤  POINT (126.99199 37.56541)              2
# 1426     82올리언즈  POINT (126.99129 37.56398)              2
# 232          부지  POINT (126.98856 37.56663)              2
# 574         주마등  POINT (126.99139 37.56534)              2
# 62           광장  POINT (126.98949 37.56691)              2
# 647          다래  POINT (126.98958 37.56533)              2
# 10           일품  POINT (126.98958 37.56533)              2
# 1578        오덕장  POINT (126.99003 37.56602)              2
# 435         을지빈  POINT (126.99220 37.56525)              2
# 1563        까이9  POINT (126.99237 37.56521)              2
# 1566       을지로밑  POINT (126.99113 37.56544)              2
# 239        만선호프  POINT (126.99177 37.56725)              1
# 486         다크문  POINT (126.99125 37.56564)              1
# 501        을지맥옥  POINT (126.99071 37.56545)              1
# 1161         애플  POINT (126.99030 37.56393)              1
# 1465        을지도  POINT (126.99055 37.56517)              1
# 148       을지로보석  POINT (126.98923 37.56513)              1
# 266        십분의일  POINT (126.99021 37.56531)              1
# 158      을지로골목집  POINT (126.99010 37.56560)              1
# 1104        굿모닝  POINT (126.99189 37.56310)              1
# 412          맨틱  POINT (126.99208 37.56613)              1
# 325         줄리아  POINT (126.99041 37.56549)              1
# 166        을지깐깐  POINT (126.99104 37.56574)              1
# 189          부스  POINT (126.99054 37.56325)              1
# 290       취향로3가  POINT (126.99147 37.56532)              1
# 382         좋은날  POINT (126.99177 37.56301)              1
# 521     금토일샴페인빠  POINT (126.99257 37.56509)              1
# 492         혜민당  POINT (126.98860 37.56647)              1
# 217        302호  POINT (126.98876 37.56662)              1
# 1433        라이너  POINT (126.99243 37.56422)              1
# 1048         만선  POINT (126.99225 37.56503)              1
# 139         전주집  POINT (126.99065 37.56541)              1
# 235         수선화  POINT (126.99164 37.56569)              1
# 1421        코너숍  POINT (126.99114 37.56556)              1
# 6           르템플  POINT (126.99240 37.56589)              1
# 380          드므  POINT (126.99146 37.56547)              1
# 1500         단칸  POINT (126.99232 37.56520)              1
# 683         가야성  POINT (126.98850 37.56649)              1
# 1550         콸콸  POINT (126.99083 37.56493)              1
# 576       남영동양문  POINT (126.98961 37.56509)              1
# 1532         영동  POINT (126.99071 37.56770)              1
# 52         을지다락  POINT (126.99141 37.56374)              1
# 89         을지로제  POINT (126.99083 37.56552)              1

# %%
gdf_store_euljiro.loc[:,'posting_count'].sum()
# Out:
# 114

# %% [markdown]
# ## pydeck으로 시각화 (탐색용)

# %%
# pydeck layer 설정

scatterplot_layer = pdk.Layer(
    'ScatterplotLayer',
    gdf_store_euljiro,
    pickable=True,
    opacity=0.3,
    stroked=False,
    filled=True,
    radius_scale=2,
    get_position='geometry.coordinates',
    get_radius='posting_count',
    get_fill_color=[255,140,0]
)

# %%
# Set the viewport location
view_state = pdk.ViewState(latitude=37.565, longitude=126.9915, zoom=15, bearing=0, pitch=0)

# Render
r = pdk.Deck(layers=[scatterplot_layer], initial_view_state=view_state, tooltip={"text": "{store_name}\n{posting_count}"})
r.to_html("../output/maps/euljiro/scatterplot_layer.html")
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.8.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;bearing&quot;: 0,
#     &quot;latitude&quot;: 37.565,
#     &quot;longitude&quot;: 126.9915,
#     &quot;pitch&quot;: 0,
#     &quot;zoom&quot;: 15
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;ScatterplotLayer&quot;,
#       &quot;data&quot;: [
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.990551970111,
#               37.565172703705
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 20,
#           &quot;store_name&quot;: &quot;\ub610\ub871&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.990264761693,
#               37.565485612454
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 4,
#           &quot;store_name&quot;: &quot;\uacf5\uac04\uac11&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.991464848233,
#               37.5654688393663
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 4,
#           &quot;store_name&quot;: &quot;\ubca0\ub85c\ub098&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.991125668811,
#               37.5654389100646
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 4,
#           &quot;store_name&quot;: &quot;\ud6a8\uacc4&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.990551970111,
#               37.565172703705
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 3,
#           &quot;store_name&quot;: &quot;\uc744\uc9c0\ub85c\ub77c\uc2a4\ubca0\uac00\uc2a4&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.991216821302,
#               37.56539463686
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 3,
#           &quot;store_name&quot;: &quot;\ubd80\uc7a5\ub2d8\ub301&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.988471247261,
#               37.566695676443
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 3,
#           &quot;store_name&quot;: &quot;\ud0c0\ub9c8\uace0&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.990551970111,
#               37.565172703705
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 3,
#           &quot;store_name&quot;: &quot;\ucf54\uc57c&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.989919378479,
#               37.5659151582608
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 3,
#           &quot;store_name&quot;: &quot;\uc744\uc9c0\uc624\ub385&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.991466913143,
#               37.5653156797688
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 3,
#           &quot;store_name&quot;: &quot;\uc744\uc9c01\ub9c9&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.99140894357,
#               37.5637383598119
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 3,
#           &quot;store_name&quot;: &quot;\ub3c8\ub3c5&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.989333512394,
#               37.5648739454013
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 3,
#           &quot;store_name&quot;: &quot;\ud1a0\ub9ac\ub178\ub77c\uc2a4\ubca0\uac00\uc2a4&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.992695541814,
#               37.5640196572389
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 2,
#           &quot;store_name&quot;: &quot;\uc6b0\ub974\ub974&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.99124749538,
#               37.5656381804481
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 2,
#           &quot;store_name&quot;: &quot;\uc5b4\ub098\ub354\ub808\ubca8&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.991986332192,
#               37.5654102201596
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 2,
#           &quot;store_name&quot;: &quot;\ubd84\uce74\uc0e4&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.991292484931,
#               37.5639806463867
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 2,
#           &quot;store_name&quot;: &quot;82\uc62c\ub9ac\uc5b8\uc988&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.988562646465,
#               37.5666333865863
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 2,
#           &quot;store_name&quot;: &quot;\ubd80\uc9c0&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.991387321958,
#               37.565342031091
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 2,
#           &quot;store_name&quot;: &quot;\uc8fc\ub9c8\ub4f1&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.98948709582,
#               37.5669116158248
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 2,
#           &quot;store_name&quot;: &qu

# %%
heatmap_layer = pdk.Layer(
    "HeatmapLayer",
    data=gdf_store_euljiro,
    opacity=0.5,
    get_position='geometry.coordinates',
    aggregation=pdk.types.String("MEAN"),
    get_weight="posting_count",
)

# %%
r = pdk.Deck(
    layers=[heatmap_layer],
    initial_view_state=view_state
)

r.to_html("../output/maps/euljiro/heatmap_layer.html")
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.8.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;bearing&quot;: 0,
#     &quot;latitude&quot;: 37.565,
#     &quot;longitude&quot;: 126.9915,
#     &quot;pitch&quot;: 0,
#     &quot;zoom&quot;: 15
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;HeatmapLayer&quot;,
#       &quot;aggregation&quot;: &quot;MEAN&quot;,
#       &quot;data&quot;: [
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.990551970111,
#               37.565172703705
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 20,
#           &quot;store_name&quot;: &quot;\ub610\ub871&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.990264761693,
#               37.565485612454
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 4,
#           &quot;store_name&quot;: &quot;\uacf5\uac04\uac11&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.991464848233,
#               37.5654688393663
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 4,
#           &quot;store_name&quot;: &quot;\ubca0\ub85c\ub098&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.991125668811,
#               37.5654389100646
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 4,
#           &quot;store_name&quot;: &quot;\ud6a8\uacc4&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.990551970111,
#               37.565172703705
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 3,
#           &quot;store_name&quot;: &quot;\uc744\uc9c0\ub85c\ub77c\uc2a4\ubca0\uac00\uc2a4&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.991216821302,
#               37.56539463686
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 3,
#           &quot;store_name&quot;: &quot;\ubd80\uc7a5\ub2d8\ub301&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.988471247261,
#               37.566695676443
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 3,
#           &quot;store_name&quot;: &quot;\ud0c0\ub9c8\uace0&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.990551970111,
#               37.565172703705
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 3,
#           &quot;store_name&quot;: &quot;\ucf54\uc57c&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.989919378479,
#               37.5659151582608
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 3,
#           &quot;store_name&quot;: &quot;\uc744\uc9c0\uc624\ub385&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.991466913143,
#               37.5653156797688
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 3,
#           &quot;store_name&quot;: &quot;\uc744\uc9c01\ub9c9&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.99140894357,
#               37.5637383598119
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 3,
#           &quot;store_name&quot;: &quot;\ub3c8\ub3c5&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.989333512394,
#               37.5648739454013
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 3,
#           &quot;store_name&quot;: &quot;\ud1a0\ub9ac\ub178\ub77c\uc2a4\ubca0\uac00\uc2a4&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.992695541814,
#               37.5640196572389
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 2,
#           &quot;store_name&quot;: &quot;\uc6b0\ub974\ub974&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.99124749538,
#               37.5656381804481
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 2,
#           &quot;store_name&quot;: &quot;\uc5b4\ub098\ub354\ub808\ubca8&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.991986332192,
#               37.5654102201596
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 2,
#           &quot;store_name&quot;: &quot;\ubd84\uce74\uc0e4&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.991292484931,
#               37.5639806463867
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 2,
#           &quot;store_name&quot;: &quot;82\uc62c\ub9ac\uc5b8\uc988&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.988562646465,
#               37.5666333865863
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 2,
#           &quot;store_name&quot;: &quot;\ubd80\uc9c0&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.991387321958,
#               37.565342031091
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&quot;: 2,
#           &quot;store_name&quot;: &quot;\uc8fc\ub9c8\ub4f1&quot;
#         },
#         {
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               126.98948709582,
#               37.5669116158248
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;posting_count&qu
